# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
data=pd.read_csv('Telco-Customer-Churn.xlsx - Telco-Customer-Churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # 1 Compare churn count with respect to gender.

# %%
plt.figure(figsize=(8,5))
data1=data[data['Churn']=='Yes' ]

sns.countplot(x=data1['Churn'],hue=data1['gender'])
plt.grid()

# %% [markdown]
# # 2) Find out how many female senior citizens there in the dataset

# %%
fem_senior=data[(data['SeniorCitizen']==1) & (data['gender']=='Female')]
fem_senior['SeniorCitizen'].value_counts()
# Out:
# 1    568
# Name: SeniorCitizen, dtype: int64

# %%
sns.countplot(x=fem_senior['SeniorCitizen'])
plt.xlabel("Female senior-citizen")
# Out:
# Text(0.5, 0, 'Female senior-citizen')

# %% [markdown]
# # 3) Compare 'tenure' with 'Total Charges'

# %%
sns.scatterplot(x='tenure',y='TotalCharges',data=data)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %% [markdown]
# # 4) Find out which contract preffered by the senior citizen.

# %%
sns.countplot(x=data[data['SeniorCitizen']==1]['Contract'])
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
#month to month contract is preffered by the senior citizen.

# %% [markdown]
# # 5)Comment on your finds on Payment Method?

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=data['PaymentMethod'])
plt.grid()

# %%
#maximum people have used electronic check as payment method
